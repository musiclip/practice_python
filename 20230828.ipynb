# %% [markdown]
# <a href="https://colab.research.google.com/github/musiclip/practice_python/blob/main/20230828.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. 데이터 그룹 연산
#     groupby, apply
#
# 2.시계열 데이터 분석

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

left = pd.DataFrame({'key': ['K0', 'K4', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})

right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                      'C': ['C0', 'C1', 'C2', 'C3'],
                      'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K4  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(left, right, on = 'key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K2  A2  B2  C2  D2
# 2  K3  A3  B3  C3  D3

# %%
pd.merge(left, right, on = 'key', how = 'outer')
# Out:
#   key    A    B    C    D
# 0  K0   A0   B0   C0   D0
# 1  K4   A1   B1  NaN  NaN
# 2  K2   A2   B2   C2   D2
# 3  K3   A3   B3   C3   D3
# 4  K1  NaN  NaN   C1   D1

# %%
pd.merge(left, right, on = 'key', how = 'left')
# Out:
#   key   A   B    C    D
# 0  K0  A0  B0   C0   D0
# 1  K4  A1  B1  NaN  NaN
# 2  K2  A2  B2   C2   D2
# 3  K3  A3  B3   C3   D3

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                   index=[0, 1, 2, 3])

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                   index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'],
                    'D': ['D8', 'D9', 'D10', 'D11']},
                   index=[8, 9, 10, 11])

# %%
pd.concat([df1, df2, df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                    'D': ['D2', 'D3', 'D6', 'D7'],
                    'F': ['F2', 'F3', 'F6', 'F7']},
                   index=[2, 3, 6, 7])

# %%
df4
# Out:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %%
pd.concat([df1, df4], axis = 1)
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
pd.concat([df1, df4], axis = 1, join = 'inner')
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %% [markdown]
# http://data.seoul.go.kr/dataList/OA-2734/F/1/datasetView.do
#
# https://data.seoul.go.kr/dataList/419/S/2/datasetView.do
#
# https://www.localdata.go.kr/lif/lifeCtacDataView.do?opnEtcSvcId=12_04_08_E

# %%
ls
# Out:
# CCTV.csv  주민등록인구.csv  sample_data/

# %%
cp 'CCTV.csv' ./CCTV_Seoul.csv

# %%
ls
# Out:
# CCTV.csv  CCTV_Seoul.csv  주민등록인구.csv  sample_data/

# %%
cat CCTV_Seoul.csv

# %%
cp '주민등록인구.csv' ./POP_Seoul.csv

# %%
ls
# Out:
# CCTV.csv  CCTV_Seoul.csv  주민등록인구.csv  POP_Seoul.csv  sample_data/

# %%
cat POP_Seoul.csv
# Out:
# ﻿"동별(1)",동별(2),2023 1/4,2023 1/4,2023 1/4,2023 1/4,2023 1/4,2023 1/4,2023 2/4,2023 2/4,2023 2/4,2023 2/4,2023 2/4
# "동별(1)",동별(2),세대 (세대),계 (명),한국인 (명),등록외국인 (명),세대당인구 (명),65세이상고령자 (명),세대 (세대),계 (명),한국인 (명),등록외국인 (명),인구밀도
# "합계",소계,4463385,9668008,9426404,241604,2.11,1690961,4469158,9659322,9414093,245229,2
# "합계",종로구,72679,152212,141060,11152,1.94,28265,72507,151349,140397,10952,2
# "합계",중구,63862,131390,120963,10427,1.89,25353,64375,132054,121441,10613,2
# "합계",용산구,109735,232482,217756,14726,1.98,39478,109679,232069,217288,14781,2
# "합계",성동구,133513,287240,280240,7000,2.10,48238,133484,286564,279374,7190,2
# "합계",광진구,169787,350925,336801,14124,1.98,54854,169857,350820,336169,14651,2
# "합계",동대문구,171140,354884,337574,17310,1.97,65154,171703,355667,338115,17552,2
# "합계",중랑구,187898,389928,385003,4925,2.05,76116,187981,389316,384272,5044,2
# "합계",성북구,197859,441855,430100,11755,2.17,78427,197831,441065,429142,11923,2
# ...

# %%
cp CCTV_Seoul.csv ./drive/MyDrive/
# Out:
# cp: cannot create regular file './drive/MyDrive/': No such file or directory

# %% [markdown]
# CCTV 데이터의 '자치구'와
#
# 인구 데이터의 '자치구'를 key로 하여 merge 해주세요.
#
# CCTV에서 '총계' 버리기

# %%
df1 = pd.read_csv('CCTV_Seoul.csv', encoding = 'euc-kr')
df2 = pd.read_csv('POP_Seoul.csv', encoding = 'utf8')
df = pd.concat([df1, df2], axis = 1, join = 'inner').drop(index = 0)

# %%
df1 = pd.read_csv('CCTV_Seoul.csv', encoding = 'euc-kr')
df2 = pd.read_csv('POP_Seoul.csv', encoding = 'utf8')
df1['총계'] = df1['총계'].str.replace(',', '').astype(int)

df1.rename(columns={'구분': '자치구'}, inplace=True)
df1['자치구'] = df1['자치구'].str.replace(' ', '').str.lower()
df1 = df1.iloc[:, 1:3]

df2.rename(columns={'동별(2)': '자치구'}, inplace=True)
df2 = df2.iloc[:, [1, 3]]


df = pd.merge(df1, df2, on='자치구')
df.columns = ['자치구', 'CCTV_total', 'PEOPLE_total']
df['PEOPLE_total'] = df['PEOPLE_total'].astype(int)

print(df.info())
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 0 to 24
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   자치구           25 non-null     object
#  1   CCTV_total    25 non-null     int64
#  2   PEOPLE_total  25 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 800.0+ bytes
# None
#      자치구  CCTV_total  PEOPLE_total
# 0    종로구        1966        152212
# 1     중구        2584        131390
# 2    용산구        2970        232482
# 3    성동구        4175        287240
# 4    광진구        3592        350925
# 5   동대문구        2759        354884
# 6    중랑구        4193        389928
# 7    성북구        4957        441855
# 8    강북구        3321        296934
# 9    도봉구        2385        312858
# 10   노원구        2626        506989
# 11   은평구        4653        468766
# 12  서대문구        3538        321966
# 13   마포구        2638        376542
# 14   양천구        3890        442345
# ...

# %%
df1 = pd.read_csv('CCTV_Seoul.csv', encoding = 'euc-kr',dtype={'총계': str})
df2 = pd.read_csv('POP_Seoul.csv', encoding = 'utf8')
df1['총계'] = df1['총계'].str.replace(',', '').astype(int)

df1.rename(columns={'구분': '자치구'}, inplace=True)
df1 = df1.iloc[:, 1:3]

df2.rename(columns={'동별(2)': '자치구'}, inplace=True)
df2 = df2.iloc[:, [1, 3]]

df1['자치구'] = df1['자치구'].str.replace(' ', '').str.lower()
df2['자치구'] = df2['자치구'].str.replace(' ', '').str.lower()

df = pd.merge(df1, df2, on = '자치구')
df.columns.values[1] = 'CCTV_total'
df.columns.values[2] = 'POP_total'

print(df.info())   #pop_total이 int처리가 되어있지않아 keyerror 발생
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CCTV_total'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

file_name = './CCTV_Seoul.csv'

# %%
cctv = pd.read_csv(file_name, encoding = 'euc-kr', thousands = ',', header = [0], skiprows = [1])

# %%
cctv.head()  #전체 자료에 구분기호 있을땐 thousands = ','로 쉽게 변경 가능
# Out:
#    Unnamed: 0   구분    총계  2014년 이전  2014년  2015년  2016년  2017년  2018년  2019년  \
# 0           1  종로구  1966     553.0    103    160    130    144    150     67
# 1           2  중 구  2584     217.0     77    236    240    372    386    155
# 2           3  용산구  2970      87.0     68     83    295    491    115    322
# 3           4  성동구  4175     157.0    110    366    281    942    457    643
# 4           5  광진구  3592     130.0    176     95     40    666    460    712
#
#    2020년  2021년  2022년  2023년
# 0    233     88    207  131.0
# 1    361    403    137    0.0
# 2    623    422    464    0.0
# 3    485    367    232  135.0
# 4    190    738    273  112.0

# %% [markdown]
# dropna(how = 'all', axis = 1)

# %%
cctv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  25 non-null     int64
#  1   구분          25 non-null     object
#  2   총계          25 non-null     int64
#  3   2014년 이전    24 non-null     float64
#  4   2014년       25 non-null     int64
#  5   2015년       25 non-null     int64
#  6   2016년       25 non-null     int64
#  7   2017년       25 non-null     int64
#  8   2018년       25 non-null     int64
#  9   2019년       25 non-null     int64
#  10  2020년       25 non-null     int64
#  11  2021년       25 non-null     int64
#  12  2022년       25 non-null     int64
#  13  2023년       22 non-null     float64
# dtypes: float64(2), int64(11), object(1)
# memory usage: 2.9+ KB

# %%
file_pop = './POP_Seoul.csv'

# %%
pop_Seoul = pd.read_csv(file_pop, skiprows = [0,2], header = [0], encoding = 'utf8')
pop_Seoul.head()
# Out:
#   동별(1) 동별(2)  세대 (세대)   계 (명)  한국인 (명)  등록외국인 (명)  세대당인구 (명)  65세이상고령자 (명)  \
# 0    합계   종로구    72679  152212   141060      11152       1.94         28265
# 1    합계    중구    63862  131390   120963      10427       1.89         25353
# 2    합계   용산구   109735  232482   217756      14726       1.98         39478
# 3    합계   성동구   133513  287240   280240       7000       2.10         48238
# 4    합계   광진구   169787  350925   336801      14124       1.98         54854
#
#    세대 (세대).1  계 (명).1  한국인 (명).1  등록외국인 (명).1  인구밀도
# 0      72507   151349     140397        10952     2
# 1      64375   132054     121441        10613     2
# 2     109679   232069     217288        14781     2
# 3     133484   286564     279374         7190     2
# 4     169857   350820     336169        14651     2

# %%
cat POP_Seoul.csv
# Out:
# ﻿"동별(1)",동별(2),2023 1/4,2023 1/4,2023 1/4,2023 1/4,2023 1/4,2023 1/4,2023 2/4,2023 2/4,2023 2/4,2023 2/4,2023 2/4
# "동별(1)",동별(2),세대 (세대),계 (명),한국인 (명),등록외국인 (명),세대당인구 (명),65세이상고령자 (명),세대 (세대),계 (명),한국인 (명),등록외국인 (명),인구밀도
# "합계",소계,4463385,9668008,9426404,241604,2.11,1690961,4469158,9659322,9414093,245229,2
# "합계",종로구,72679,152212,141060,11152,1.94,28265,72507,151349,140397,10952,2
# "합계",중구,63862,131390,120963,10427,1.89,25353,64375,132054,121441,10613,2
# "합계",용산구,109735,232482,217756,14726,1.98,39478,109679,232069,217288,14781,2
# "합계",성동구,133513,287240,280240,7000,2.10,48238,133484,286564,279374,7190,2
# "합계",광진구,169787,350925,336801,14124,1.98,54854,169857,350820,336169,14651,2
# "합계",동대문구,171140,354884,337574,17310,1.97,65154,171703,355667,338115,17552,2
# "합계",중랑구,187898,389928,385003,4925,2.05,76116,187981,389316,384272,5044,2
# "합계",성북구,197859,441855,430100,11755,2.17,78427,197831,441065,429142,11923,2
# ...

# %%
pop_data = pop_Seoul.loc[:, [pop_Seoul.columns[1], pop_Seoul.columns[3]]]
pop_data.rename(columns = {'동별(2)': 'gu', '계 (명)':'pop_total'}, inplace = True)

# %%
cctv.rename(columns = {'구분':'gu', '총계':'cctv_total'}, inplace = True)

# %%
cctv.head()
# Out:
#    Unnamed: 0   gu  cctv_total  2014년 이전  2014년  2015년  2016년  2017년  2018년  \
# 0           1  종로구        1966     553.0    103    160    130    144    150
# 1           2  중 구        2584     217.0     77    236    240    372    386
# 2           3  용산구        2970      87.0     68     83    295    491    115
# 3           4  성동구        4175     157.0    110    366    281    942    457
# 4           5  광진구        3592     130.0    176     95     40    666    460
#
#    2019년  2020년  2021년  2022년  2023년
# 0     67    233     88    207  131.0
# 1    155    361    403    137    0.0
# 2    322    623    422    464    0.0
# 3    643    485    367    232  135.0
# 4    712    190    738    273  112.0

# %%
cctv_data = cctv[['gu','cctv_total']]

# %%
cctv_data
# Out:
#       gu  cctv_total
# 0    종로구        1966
# 1    중 구        2584
# 2    용산구        2970
# 3    성동구        4175
# 4    광진구        3592
# 5   동대문구        2759
# 6    중랑구        4193
# 7    성북구        4957
# 8    강북구        3321
# 9    도봉구        2385
# 10   노원구        2626
# 11   은평구        4653
# 12  서대문구        3538
# 13   마포구        2638
# 14   양천구        3890
# 15   강서구        3353
# 16   구로구        4831
# 17   금천구        2885
# 18  영등포구        4660
# 19   동작구        2690
# 20   관악구        5642
# 21   서초구        4995
# 22   강남구        7243
# 23   송파구        3253
# 24   강동구        3192

# %%
gu_list = list(cctv_data.gu)
for i in pop_data.gu:
    if i in gu_list:
        pass
    else:
        print(i)
# Out:
# 중구

# %%
cctv_data.gu
# Out:
# 0      종로구
# 1      중 구
# 2      용산구
# 3      성동구
# 4      광진구
# 5     동대문구
# 6      중랑구
# 7      성북구
# 8      강북구
# 9      도봉구
# 10     노원구
# 11     은평구
# 12    서대문구
# 13     마포구
# 14     양천구
# 15     강서구
# 16     구로구
# 17     금천구
# 18    영등포구
# 19     동작구
# 20     관악구
# 21     서초구
# 22     강남구
# 23     송파구
# 24     강동구
# Name: gu, dtype: object

# %%
cctv_data['gu']=cctv_data['gu'].str.replace(' ','')
# Out:
# <ipython-input-27-4c917fff64c7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cctv_data['gu']=cctv_data['gu'].str.replace(' ','')

# %%
data = pd.merge(cctv_data,pop_data, on ='gu')

# %%
data
# Out:
#       gu  cctv_total  pop_total
# 0    종로구        1966     152212
# 1     중구        2584     131390
# 2    용산구        2970     232482
# 3    성동구        4175     287240
# 4    광진구        3592     350925
# 5   동대문구        2759     354884
# 6    중랑구        4193     389928
# 7    성북구        4957     441855
# 8    강북구        3321     296934
# 9    도봉구        2385     312858
# 10   노원구        2626     506989
# 11   은평구        4653     468766
# 12  서대문구        3538     321966
# 13   마포구        2638     376542
# 14   양천구        3890     442345
# 15   강서구        3353     573711
# 16   구로구        4831     417983
# 17   금천구        2885     242467
# 18  영등포구        4660     398999
# 19   동작구        2690     390377
# 20   관악구        5642     502628
# 21   서초구        4995     408979
# 22   강남구        7243     537817
# 23   송파구        3253     663704
# 24   강동구        3192     464027

# %% [markdown]
# 선형성 : 종속변수와 독립변수 간의 선형 관계
#
#     선형
#         가산성(Additivity) : f(x1 + x2) = f(x1) + f(x2)
#
#         동차성(Homegeneity) : f(kx) = kf(x)
#
#         https://satlab.tistory.com/90
#
# 독립성 : 다중회귀에서 독립 변수들 간의 통계적 독립성(비 다중공선성)
#
#     다중공선성(multivollinearity)란 독립변수의 일부가 다른 독립 변수의 조합으로 표현될 수 있는 경우이다.
#
#     통계학의 회귀분석에서 독립변수들 간에 강한 상관관계가 나타나는 문제이다.
#
# 등분산성: 잔차들의 분산이 일정
#
# 정규성 : 잔차들의 분포가 정규 분포를 이룸

# %% [markdown]
# 종속변수 : y = f(x)
#
# 독립변수 : x
#
# f(x) = x1 + x2 +x3 + 1

# %%
from sklearn.linear_model import LinearRegression

# %%
data.cctv_total.shape
# Out:
# (25,)

# %%
data.pop_total.shape
# Out:
# (25,)

# %%
data.shape
# Out:
# (25, 3)

# %% [markdown]
# y = cctv 개수
#
# x = 인구수

# %%
x = data.pop_total[:, np.newaxis]
# Out:
# <ipython-input-34-99567e8d120d>:1: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = data.pop_total[:, np.newaxis]

# %%
x.shape
# Out:
# (25, 1)

# %%
x
# Out:
# array([[152212],
#        [131390],
#        [232482],
#        [287240],
#        [350925],
#        [354884],
#        [389928],
#        [441855],
#        [296934],
#        [312858],
#        [506989],
#        [468766],
#        [321966],
#        [376542],
#        [442345],
#        [573711],
#        [417983],
#        [242467],
#        [398999],
#        [390377],
#        [502628],
#        [408979],
#        [537817],
#        [663704],
#        [464027]])

# %%
x = data.pop_total.values.reshape(-1,1)

# %%
x
# Out:
# array([[152212],
#        [131390],
#        [232482],
#        [287240],
#        [350925],
#        [354884],
#        [389928],
#        [441855],
#        [296934],
#        [312858],
#        [506989],
#        [468766],
#        [321966],
#        [376542],
#        [442345],
#        [573711],
#        [417983],
#        [242467],
#        [398999],
#        [390377],
#        [502628],
#        [408979],
#        [537817],
#        [663704],
#        [464027]])

# %%
y = data.cctv_total

# %%
y
# Out:
# 0     1966
# 1     2584
# 2     2970
# 3     4175
# 4     3592
# 5     2759
# 6     4193
# 7     4957
# 8     3321
# 9     2385
# 10    2626
# 11    4653
# 12    3538
# 13    2638
# 14    3890
# 15    3353
# 16    4831
# 17    2885
# 18    4660
# 19    2690
# 20    5642
# 21    4995
# 22    7243
# 23    3253
# 24    3192
# Name: cctv_total, dtype: int64

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# y = ax + b
#
# a : coef_
#
# b : intercept_

# %%
model.coef_
# Out:
# array([0.00449036])

# %%
model.intercept_
# Out:
# 1983.127310077079

# %%
data['predict_lr'] = model.predict(x)

# %%
data.head()  #데이터가 3개 이상이면 그래프를 그려서 보는것이 좋음
# Out:
#     gu  cctv_total  pop_total   predict_lr
# 0  종로구        1966     152212  2666.613685
# 1   중구        2584     131390  2573.115450
# 2  용산구        2970     232482  3027.054723
# 3  성동구        4175     287240  3272.937747
# 4  광진구        3592     350925  3558.906198

# %% [markdown]
# 2. numpy 이용

# %%
fp1 = np.polyfit(data.pop_total, data.cctv_total,1)   #(x,y,n차원 결정)

# %%
fp1
# Out:
# array([4.49035802e-03, 1.98312731e+03])

# %%
func = np.poly1d(fp1)

# %%
data['predict'] = func(data.pop_total)

# %%
data.head()
# Out:
#     gu  cctv_total  pop_total   predict_lr      predict
# 0  종로구        1966     152212  2666.613685  2666.613685
# 1   중구        2584     131390  2573.115450  2573.115450
# 2  용산구        2970     232482  3027.054723  3027.054723
# 3  성동구        4175     287240  3272.937747  3272.937747
# 4  광진구        3592     350925  3558.906198  3558.906198

# %%
data['res'] = data.cctv_total - data.predict_lr

# %%
data.head()
# Out:
#     gu  cctv_total  pop_total   predict_lr      predict         res
# 0  종로구        1966     152212  2666.613685  2666.613685 -700.613685
# 1   중구        2584     131390  2573.115450  2573.115450   10.884550
# 2  용산구        2970     232482  3027.054723  3027.054723  -57.054723
# 3  성동구        4175     287240  3272.937747  3272.937747  902.062253
# 4  광진구        3592     350925  3558.906198  3558.906198   33.093802

# %%
data_sort = data.sort_values(by = 'res', ascending = False)

# %%
data_sort.head()
# Out:
#      gu  cctv_total  pop_total   predict_lr      predict          res
# 22  강남구        7243     537817  4398.118189  4398.118189  2844.881811
# 20  관악구        5642     502628  4240.106980  4240.106980  1401.893020
# 21  서초구        4995     408979  3819.589442  3819.589442  1175.410558
# 7   성북구        4957     441855  3967.214452  3967.214452   989.785548
# 16  구로구        4831     417983  3860.020626  3860.020626   970.979374

# %%
data_sort = data_sort.reset_index(drop = True)

# %%
data_sort.head()
# Out:
#     gu  cctv_total  pop_total   predict_lr      predict          res
# 0  강남구        7243     537817  4398.118189  4398.118189  2844.881811
# 1  관악구        5642     502628  4240.106980  4240.106980  1401.893020
# 2  서초구        4995     408979  3819.589442  3819.589442  1175.410558
# 3  성북구        4957     441855  3967.214452  3967.214452   989.785548
# 4  구로구        4831     417983  3860.020626  3860.020626   970.979374

# %%
from matplotlib import font_manager
font_path = './NanumGothic.ttf'
fontprop = font_manager.FontProperties(fname = font_path, size = 20)

# %% [markdown]
# plt.text(x위치, y위치, 텍스트 문자)

# %%
plt.figure(figsize = (8,8))
plt.scatter(data_sort.pop_total, data_sort.cctv_total, c = data_sort.res, s = 50)
plt.plot(data_sort.pop_total, data_sort.predict_lr, ls = '-',lw = 1, color = 'red')

for n in range(3):
    plt.text(data_sort.loc[n, 'pop_total']*1.02, data_sort.loc[n, 'cctv_total']*1.02, data_sort.loc[n, 'gu'],fontsize = 10,fontproperties = fontprop)
for n in range(23, 25):
    plt.text(data_sort.loc[n, 'pop_total']*1.02, data_sort.loc[n, 'cctv_total']*1.02, data_sort.loc[n, 'gu'],fontsize = 10,fontproperties = fontprop)
plt.colorbar()
plt.grid()
plt.ylabel('CCTV 개수', fontproperties = fontprop)
plt.xlabel('인구수',fontproperties = fontprop)
plt.show()

# %% [markdown]
# ---
# ---
# Groupby
#
# ![image.png](data:image/png;base64,...)

# %%
df = pd.DataFrame({'key1':['a','a','b','b','a'],
                   'key2':['one','two','one','two','one'],
                   'data1': [1,2,3,4,5],
                   'data2': [10, 20, 30, 40, 50]})

# %%
df
# Out:
#   key1 key2  data1  data2
# 0    a  one      1     10
# 1    a  two      2     20
# 2    b  one      3     30
# 3    b  two      4     40
# 4    a  one      5     50

# %%
grouped = df['data1'].groupby(df['key1'])  #key1을 기준으로 그룹

# %%
grouped

# %%
grouped.sum()
# Out:
# key1
# a    8
# b    7
# Name: data1, dtype: int64

# %%
ls
# Out:
# 12_04_01_E_공중화장실정보.xlsx  CCTV_Seoul.csv    NanumGothic.ttf  sample_data/
# CCTV.csv                        주민등록인구.csv  POP_Seoul.csv

# %%
ls
# Out:
# 12_04_08_E_CCTV정보.xlsx  CCTV_Seoul.csv    NanumGothic.ttf  sample_data/
# CCTV.csv                  주민등록인구.csv  POP_Seoul.csv

# %%
df1 = pd.read_excel('12_04_08_E_CCTV정보.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df1 = df1.loc[:,[df1.columns[1]]]
df1['구'] = df1['관리기관명'].str.replace('서울특별시 ', '').str.replace('청', '').str.replace('서울시 ','')
result = df1['구'].groupby(df1['구']).count()
df = pd.DataFrame({'구': result.index, 'CCTV 개수': result.values})
df['구'] = df['구'].str.replace(' U-통합운영센터','')
df #도봉이 강북으로 포함되어있음
# Out:
#        구  CCTV 개수
# 0    강남구     6178
# 1    강동구     1192
# 2    강북구     2957
# 3    강서구     1666
# 4    관악구     1753
# 5    광진구     1078
# 6    구로구     1779
# 7    금천구      778
# 8    노원구     2626
# 9   동대문구      976
# 10   동작구      890
# 11   마포구     1225
# 12  서대문구      867
# 13   서초구     4995
# 14   성동구     1314
# 15   성북구     1781
# 16   송파구     1244
# 17   양천구     3417
# 18  영등포구     4397
# 19   용산구      808
# 20   은평구     1789
# 21   종로구      797
# 22    중구     1026
# 23   중랑구     1228

# %%
df = df.rename(index = {'U-통합운영센':'금천구'}, inplace = True)

# %%
df

# %%
grouped_df.count()

# %%
df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'Max_Speed': [380., 370., 24., 26.]})

# %%
df
# Out:
#    Animal  Max_Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
grouped_df = df['Max_Speed'].groupby(df['Animal'])

# %%
grouped_df = df['Max_Speed'].groupby(df['Animal'])
print(grouped_df.sum())
print(grouped_df.mean())
# Out:
# Animal
# Falcon    750.0
# Parrot     50.0
# Name: Max_Speed, dtype: float64
# Animal
# Falcon    375.0
# Parrot     25.0
# Name: Max_Speed, dtype: float64

# %%
arrays = [['Falcon', 'Falcon', 'Parrot', 'Parrot'],
          ['Captive', 'Wild', 'Captive', 'Wild']]
index = pd.MultiIndex.from_arrays(arrays, names=('Animal', 'Type'))
df = pd.DataFrame({'Max_Speed': [350., 390., 20., 30.]},
                  index=index)

# %%
df
# Out:
#                 Max_Speed
# Animal Type
# Falcon Captive      350.0
#        Wild         390.0
# Parrot Captive       20.0
#        Wild          30.0

# %%
df.groupby(level = 0).sum()   #level = 0 은 첫번째 인덱스
# Out:
#         Max_Speed
# Animal
# Falcon      740.0
# Parrot       50.0

# %%
df.groupby(level = 1).sum()
# Out:
#          Max_Speed
# Type
# Captive      370.0
# Wild         420.0

# %%
gpd = df.Max_Speed.groupby(level = 0)
gpd.mean()
# Out:
# Animal
# Falcon    370.0
# Parrot     25.0
# Name: Max_Speed, dtype: float64

# %%
gpd.min()
# Out:
# Animal
# Falcon    350.0
# Parrot     20.0
# Name: Max_Speed, dtype: float64

# %%
df.groupby(level = 'Animal').mean()
# Out:
#         Max_Speed
# Animal
# Falcon      370.0
# Parrot       25.0

# %%
list_s = [[1, 2, 3], [1, None, 4], [2, 1, 3], [1, 2, 2]]
df = pd.DataFrame(list_s, columns=["a", "b", "c"])

# %%
df
# Out:
#    a    b  c
# 0  1  2.0  3
# 1  1  NaN  4
# 2  2  1.0  3
# 3  1  2.0  2

# %%
df.groupby(by = ['b']).sum()
# Out:
#      a  c
# b
# 1.0  2  3
# 2.0  2  5

# %%
df.groupby(by = ['b'], dropna = False).sum()
# Out:
#      a  c
# b
# 1.0  2  3
# 2.0  2  5
# NaN  1  4

# %%
df = pd.DataFrame({'상품번호' : ['P1', 'P1', 'P2', 'P2'],
                   '수량' :     [2, 3, 5, 10]})

# %%
df
# Out:
#   상품번호  수량
# 0   P1   2
# 1   P1   3
# 2   P2   5
# 3   P2  10

# %%
df.groupby(by = ['상품번호']).sum()
# Out:
#       수량
# 상품번호
# P1     5
# P2    15

# %%
df.groupby(by = ['상품번호']).size()
# Out:
# 상품번호
# P1    2
# P2    2
# dtype: int64

# %%
df.groupby(by = ['상품번호']).min()
# Out:
#       수량
# 상품번호
# P1     2
# P2     5

# %%
df.groupby(by = ['상품번호']).count()
# Out:
#       수량
# 상품번호
# P1     2
# P2     2

# %%
df.groupby(by = ['상품번호'], as_index = False).count()
# Out:
#   상품번호  수량
# 0   P1   2
# 1   P2   2

# %%
df = pd.DataFrame({'고객번호' : ['C1', 'C2', 'C2', 'C2'],
                   '상품번호' : ['P1', 'P1', 'P2', 'P2'],
                   '수량' :     [2, 3, 5, 10]})

# %%
df
# Out:
#   고객번호 상품번호  수량
# 0   C1   P1   2
# 1   C2   P1   3
# 2   C2   P2   5
# 3   C2   P2  10

# %% [markdown]
# 고객번호, 상품번호로 그룹화하고 합계를 내어주세요

# %%
df.groupby(by = ['고객번호']).sum()
df.groupby(by = ['상품번호']).sum()
# Out:
# <ipython-input-172-3daf9167481e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(by = ['고객번호']).sum()
# <ipython-input-172-3daf9167481e>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(by = ['상품번호']).sum()
#       수량
# 상품번호
# P1     5
# P2    15

# %%
df.groupby(['고객번호','상품번호'], as_index = False).sum()
# Out:
#   고객번호 상품번호  수량
# 0   C1   P1   2
# 1   C2   P1   3
# 2   C2   P2  15

# %%
df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'],
                   'key2' : ['one', 'two', 'one', 'two', 'one'],
                   'data1' : [1,2,3,4,5],
                   'data2' : [10,20,30,40,50]})

# %%
df
# Out:
#   key1 key2  data1  data2
# 0    a  one      1     10
# 1    a  two      2     20
# 2    b  one      3     30
# 3    b  two      4     40
# 4    a  one      5     50

# %%
for (k1, k2), group in df.groupby(['key1', 'key2']):
    print(k1, k2)
    print(group)
    print('='*10)
# Out:
# a one
#   key1 key2  data1  data2
# 0    a  one      1     10
# 4    a  one      5     50
# ...
# a two
#   key1 key2  data1  data2
# 1    a  two      2     20
# ...
# b one
#   key1 key2  data1  data2
# 2    b  one      3     30
# ...
# b two
#   key1 key2  data1  data2
# 3    b  two      4     40
# ...

# %%
g = list(df.groupby(['key1']))
# Out:
# <ipython-input-181-61c199a1b46e>:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   g = list(df.groupby(['key1']))

# %%
g[0][1]
# Out:
#   key1 key2  data1  data2
# 0    a  one      1     10
# 1    a  two      2     20
# 4    a  one      5     50

# %%
d_g = dict(g)

# %%
d_g
# Out:
# {'a':   key1 key2  data1  data2
#  0    a  one      1     10
#  1    a  two      2     20
#  4    a  one      5     50,
#  'b':   key1 key2  data1  data2
#  2    b  one      3     30
#  3    b  two      4     40}

# %%
d_g['b']
# Out:
#   key1 key2  data1  data2
# 2    b  one      3     30
# 3    b  two      4     40

# %%
df.groupby(['key1','key2'])['data2'].sum()
# Out:
# key1  key2
# a     one     60
#       two     20
# b     one     30
#       two     40
# Name: data2, dtype: int64

# %%
people = pd.DataFrame(np.random.randn(5, 5),
                      columns=['a', 'b', 'c', 'd', 'e'],
                      index=['Joe', 'Steve', 'Wes', 'Jim', 'Travis'])
people.iloc[2:3, [1, 2]] = np.nan # Add a few NA values

# %%
people
# Out:
#                a         b         c         d         e
# Joe    -0.342236  0.700990 -2.039927  0.134652 -1.472974
# Steve  -0.387038 -0.435303 -0.473415  0.562985  0.852857
# Wes     0.757061       NaN       NaN -0.741024  1.730010
# Jim    -1.391643  0.009240  0.807663 -1.815938 -0.347676
# Travis  0.641024  0.033688 -0.721247 -1.146214 -0.921744

# %%
mapping = {'a': 'red', 'b': 'red', 'c': 'blue',
           'd': 'blue', 'e': 'red', 'f' : 'orange'}

# %%
mapping
# Out:
# {'a': 'red', 'b': 'red', 'c': 'blue', 'd': 'blue', 'e': 'red', 'f': 'orange'}

# %%
by_column = people.groupby(mapping, axis = 1)

# %%
by_column.sum()
# Out:
#             blue       red
# Joe    -1.905274 -1.114221
# Steve   0.089570  0.030517
# Wes    -0.741024  2.487072
# Jim    -1.008275 -1.730080
# Travis -1.867461 -0.247031

# %%
map_series = pd.Series(mapping)

# %%
map_series
# Out:
# a       red
# b       red
# c      blue
# d      blue
# e       red
# f    orange
# dtype: object

# %%
people.groupby(map_series, axis = 1).count()
# Out:
#         blue  red
# Joe        2    3
# Steve      2    3
# Wes        1    2
# Jim        2    3
# Travis     2    3

# %%
df.groupby(lambda x : x)

# %%
people.groupby(len).count()
# Out:
#    a  b  c  d  e
# 3  3  2  2  3  3
# 5  1  1  1  1  1
# 6  1  1  1  1  1

# %%
people.groupby(len).sum() #사람 이름의 길이로 ex) Joe = 3, Steve = 4
# Out:
#           a         b         c         d         e
# 3 -0.976818  0.710230 -1.232263 -2.422310 -0.090641
# 5 -0.387038 -0.435303 -0.473415  0.562985  0.852857
# 6  0.641024  0.033688 -0.721247 -1.146214 -0.921744

# %%
key_list = ['one','one','one','two','two']

# %%
people.groupby([len, key_list]).min()
# Out:
#               a         b         c         d         e
# 3 one -0.342236  0.700990 -2.039927 -0.741024 -1.472974
#   two -1.391643  0.009240  0.807663 -1.815938 -0.347676
# 5 one -0.387038 -0.435303 -0.473415  0.562985  0.852857
# 6 two  0.641024  0.033688 -0.721247 -1.146214 -0.921744

# %%
for i, j in people.groupby([len, key_list]):
    print(i)
    print(j)
    print('='* 10)
# Out:
# (3, 'one')
#             a        b         c         d         e
# Joe -0.342236  0.70099 -2.039927  0.134652 -1.472974
# Wes  0.757061      NaN       NaN -0.741024  1.730010
# ...
# (3, 'two')
#             a        b         c         d         e
# Jim -1.391643  0.00924  0.807663 -1.815938 -0.347676
# ...
# (5, 'one')
#               a         b         c         d         e
# Steve -0.387038 -0.435303 -0.473415  0.562985  0.852857
# ...
# (6, 'two')
#                a         b         c         d         e
# Travis  0.641024  0.033688 -0.721247 -1.146214 -0.921744
# ...

# %%
columns = pd.MultiIndex.from_arrays([['US', 'US', 'US', 'JP', 'JP'],
                                    [1, 3, 5, 1, 3]],
                                    names=['cty', 'tenor'])
h_df = pd.DataFrame(np.random.randn(4, 5), columns=columns)

# %%
h_df
# Out:
# cty          US                            JP
# tenor         1         3         5         1         3
# 0      0.797931 -1.403510  0.545934  0.891645  0.348061
# 1      0.670073  0.467234  0.101168 -0.387057 -0.320733
# 2     -0.180023  0.786496  0.921584  0.686476  0.918323
# 3      0.363876 -2.183484 -0.252173  0.339567  0.612520

# %%
h_df.groupby(level = 'cty', axis = 1).count()
# Out:
# cty  JP  US
# 0     2   3
# 1     2   3
# 2     2   3
# 3     2   3

# %%
df
# Out:
#   key1 key2  data1  data2
# 0    a  one      1     10
# 1    a  two      2     20
# 2    b  one      3     30
# 3    b  two      4     40
# 4    a  one      5     50

# %%
grouped = df.groupby('key1')

# %%
grouped['data1'].quantile(0.5)
# Out:
# key1
# a    2.0
# b    3.5
# Name: data1, dtype: float64

# %%
grouped.describe()
# Out:
#      data1                                                data2             \
#      count      mean       std  min   25%  50%   75%  max count       mean
# key1
# a      3.0  2.666667  2.081666  1.0  1.50  2.0  3.50  5.0   3.0  26.666667
# b      2.0  3.500000  0.707107  3.0  3.25  3.5  3.75  4.0   2.0  35.000000
#
#
#             std   min   25%   50%   75%   max
# key1
# a     20.816660  10.0  15.0  20.0  35.0  50.0
# b      7.071068  30.0  32.5  35.0  37.5  40.0

# %% [markdown]
# agg : apply의 특별한 경우, 결과값이 하나로 산출되는 경우
#
# 통계량(statistics): 합계, 평균, 분산. 표준편차, 최소값, 최대값, 중앙값...
#
# apply : df, Series, 스칼라 모든 경우로 산출되는 경우

# %%
cat tips.csv

# %%
tips = pd.read_csv('tips.csv',encoding = 'utf8')

# %%
tips
# Out:
#      total_bill   tip smoker   day    time  size   tip_pct
# 0         16.99  1.01     No   Sun  Dinner     2  0.059447
# 1         10.34  1.66     No   Sun  Dinner     3  0.160542
# 2         21.01  3.50     No   Sun  Dinner     3  0.166587
# 3         23.68  3.31     No   Sun  Dinner     2  0.139780
# 4         24.59  3.61     No   Sun  Dinner     4  0.146808
# ..          ...   ...    ...   ...     ...   ...       ...
# 239       29.03  5.92     No   Sat  Dinner     3  0.203927
# 240       27.18  2.00    Yes   Sat  Dinner     2  0.073584
# 241       22.67  2.00    Yes   Sat  Dinner     2  0.088222
# 242       17.82  1.75     No   Sat  Dinner     2  0.098204
# 243       18.78  3.00     No  Thur  Dinner     2  0.159744
#
# [244 rows x 7 columns]

# %%
gpd = tips.groupby(['day','smoker'])

# %%
for i, gr in gpd:
    print(i)
    print(gr)
    print('='*20)

# %%
gpd['tip_pct'].agg('mean')
# Out:
# day   smoker
# Fri   No        0.151650
#       Yes       0.174783
# Sat   No        0.158048
#       Yes       0.147906
# Sun   No        0.160113
#       Yes       0.187250
# Thur  No        0.160298
#       Yes       0.163863
# Name: tip_pct, dtype: float64

# %%
gpd['tip_pct'].agg(['mean','std'])
# Out:
#                  mean       std
# day  smoker
# Fri  No      0.151650  0.028123
#      Yes     0.174783  0.051293
# Sat  No      0.158048  0.039767
#      Yes     0.147906  0.061375
# Sun  No      0.160113  0.042347
#      Yes     0.187250  0.154134
# Thur No      0.160298  0.038774
#      Yes     0.163863  0.039389

# %%
gpd['tip_pct'].agg([('foo','mean'),('bar',np.std)])
# Out:
#                   foo       bar
# day  smoker
# Fri  No      0.151650  0.028123
#      Yes     0.174783  0.051293
# Sat  No      0.158048  0.039767
#      Yes     0.147906  0.061375
# Sun  No      0.160113  0.042347
#      Yes     0.187250  0.154134
# Thur No      0.160298  0.038774
#      Yes     0.163863  0.039389
